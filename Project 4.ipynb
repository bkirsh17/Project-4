# %%
# %run Group_1.py --mass=1.039 --FeMg=1.72 --SiMg=1.124
# Out:
# Core composition:  {'Fe': 100.0, 'Si': 0.0, 'O': 0.0, 'S': 0.0}
# Mantle composition:  {'FeO': 0.0, 'SiO2': 58.04308119, 'MgO': 34.63998566, 'CaO': 3.37365274, 'Al2O3': 3.9432804}
# Mantle Fe# -0.0
# Core Mass Percent =  45.221
#
# Your closest grid filename is:  0.07CaMg_0.00FeMg_0.09AlMg_1.1SiMg_0.0NaMg_0.00Fe_U/LM_results.txt
#
#
# Core composition:  {'Fe': 100.0, 'Si': 0.0, 'O': 0.0, 'S': 0.0}
# Mantle composition:  {'FeO': 0.0, 'SiO2': 58.04308119, 'MgO': 34.63998566, 'CaO': 3.37365274, 'Al2O3': 3.9432804}
# Mantle Fe# -0.0
# Core Mass Percent =  45.221
#
# The Upper mantle .tab already exists, please wait briefly for solution
#
# ../Solutions_Small/0.07CaMg_0.00FeMg_0.09AlMg_1.1SiMg_0.0NaMg_0.00Fe
# The Lower mantle .tab already exists, please wait briefly for solution
#
# iteration # 1
# iteration # 2
# iteration # 3
# iteration # 4
# iteration # 5
# iteration # 6
# iteration # 7
# iteration # 8
# iteration # 9
# iteration # 10
# iteration # 11
# iteration # 12
# ...

# %%
# %run Group_1.py --mass=1.039 --FeMg=1.72 --SiMg=1.124 --wt_frac_O_core=0.255
# Out:
# Core composition:  {'Fe': 74.5, 'Si': 0.0, 'O': 25.5, 'S': 0.0}
# Mantle composition:  {'FeO': 0.0, 'SiO2': 58.04308119, 'MgO': 34.63998566, 'CaO': 3.37365274, 'Al2O3': 3.9432804}
# Mantle Fe# -0.0
# Core Mass Percent =  52.563
#
# Your closest grid filename is:  0.07CaMg_0.00FeMg_0.09AlMg_1.1SiMg_0.0NaMg_0.00Fe_U/LM_results.txt
#
#
# Core composition:  {'Fe': 74.5, 'Si': 0.0, 'O': 25.5, 'S': 0.0}
# Mantle composition:  {'FeO': 0.0, 'SiO2': 58.04308119, 'MgO': 34.63998566, 'CaO': 3.37365274, 'Al2O3': 3.9432804}
# Mantle Fe# -0.0
# Core Mass Percent =  52.563
#
# The Upper mantle .tab already exists, please wait briefly for solution
#
# ../Solutions_Small/0.07CaMg_0.00FeMg_0.09AlMg_1.1SiMg_0.0NaMg_0.00Fe
# The Lower mantle .tab already exists, please wait briefly for solution
#
# iteration # 1
# iteration # 2
# iteration # 3
# iteration # 4
# iteration # 5
# iteration # 6
# iteration # 7
# iteration # 8
# iteration # 9
# iteration # 10
# iteration # 11
# iteration # 12
# ...
